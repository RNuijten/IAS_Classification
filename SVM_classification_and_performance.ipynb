# %% [markdown]
# # Weed Mapping using SVM - Thistle - 8 bands
# ### Used after collecting sampling data

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import rasterio
import rioxarray
import geopandas as gpd
import os
import glob
import pickle
import re
from joblib import Parallel, delayed
from simpledbf import Dbf5


from sklearn import svm, metrics
from sklearn.cluster import MiniBatchKMeans
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.inspection import permutation_importance
from ttictoc import tic,toc
# Out:
# PyTables is not installed. No support for HDF output.

# %%
# Band combinations
_8bands = ['1_red','1_green','1_blue','2_blue','2_green','3_red','4_re','2_nir']
_5bands = ['2_blue','2_green','3_red','4_re','2_nir']
_3bands = ['1_red','1_green','1_blue']


pathsMaj = glob.glob('E:\Sync\_Documents\_Letter_invasives\_Data\_samples\_majority_*.dbf')
pathsMin = glob.glob('E:\Sync\_Documents\_Letter_invasives\_Data\_samples\_minority_*.dbf')

# %% [markdown]
# ### Derive K-means centers for 'majority' class

# %%
def peform_k_clustering(samplesDf, bandselection, species):
    
    # k is similar to number of samples in minority class
    k = 255
    
    if species=='T':
        label = 'majorityT'
    else:
        label = 'majorityH'

    df = samplesDf[samplesDf['class']==label].loc[:,bandselection] # Get minority samples
    arr = df.to_numpy()

    # STEP 2: Perform Kmeans
    kmeansBatch = MiniBatchKMeans(n_clusters=k, init='k-means++',
                    n_init=20, max_iter=200,
                    verbose=0, random_state=0,
                    batch_size=1024).fit(arr)

    dfOut = pd.DataFrame(kmeansBatch.cluster_centers_, columns=bandselection)
    dfOut['class'] = 0 # majority label
    
    dfMin = samplesDf[samplesDf['class']==species].loc[:,bandselection]
    dfMin['class'] = 1 # minority/target label
    dfOut = pd.concat([dfOut,dfMin], axis=0)
    
    return(dfOut)

# %% [markdown]
# ### Step 3: Grid Search

# %%
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_grid_search_digits.html
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

def grid_search(trainDf, testDf, modelPath, bandselection, tuned_parameters, scores, species, seed, outCsv):
    trainDf = peform_k_clustering(trainDf, bandselection, species)
    
    # Manipulate test dataset
    if species=='T':
        testDf = testDf.loc[(testDf['class']=='T')|(testDf['class']=='majorityT')]
        testDf.loc[:,'class']  = np.where(testDf['class']=='T', 1, 0)
        
    else:    
        testDf = testDf.loc[(testDf['class']=='H')|(testDf['class']=='majorityH')]
        testDf.loc[:,'class']  = np.where(testDf['class']=='H', 1, 0)
    
#     for score in scores:
#         print("# Tuning hyper-parameters for %s" % score)
#         print()

#         clf = GridSearchCV(SVC(), tuned_parameters, scoring=score, verbose=3, n_jobs=11, pre_dispatch = '2*n_jobs')
#         clf.fit(trainDf.loc[:, bandselection].to_numpy(), trainDf.loc[:,'class'].to_numpy())

#         print("Best parameters set found on development set:")
#         print()
#         print(clf.best_params_)
#         print()
#         print("Grid scores on development set:")
#         print()
#         means = clf.cv_results_["mean_test_score"]
#         stds = clf.cv_results_["std_test_score"]
#         for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
#             print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
#         print()

#         print("Detailed classification report:")
#         print()
#         print("The model is trained on the full development set.")
#         print("The scores are computed on the full evaluation set.")
#         print()
#         y_true, y_pred = testDf.loc[:,'class'].to_numpy(), clf.predict(testDf.loc[:,bandselection].to_numpy())
#         print(classification_report(y_true, y_pred))
#         print()
        
#         print("Classification matrix:")
#         print()
#         matrix = metrics.confusion_matrix(y_true, y_pred)
#         print(matrix)
#         print()
           

     
    print("# Tuning hyper-parameters for %s" % scores)
    print()
    
    clf = GridSearchCV(SVC(), tuned_parameters, scoring=scores, verbose=3, n_jobs=11, pre_dispatch = '2*n_jobs')
    clf.fit(trainDf.loc[:, bandselection].to_numpy(), trainDf.loc[:,'class'].to_numpy())
    
    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_["mean_test_score"]
    stds = clf.cv_results_["std_test_score"]
    for mean, std, params in zip(means, stds, clf.cv_results_["params"]):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    print()
    
    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = testDf.loc[:,'class'].to_numpy(), clf.predict(testDf.loc[:,bandselection].to_numpy())
    report = classification_report(y_true, y_pred)
    print(report)
    print()

    print("Classification matrix:")
    print()
    matrix = metrics.confusion_matrix(y_true, y_pred)
    print(matrix)
    print()
    
    modelPath = modelPath.format(seed, species, str(len(bandselection)))
    pickle.dump(clf, open(modelPath, 'wb'))
    
    # organize metrics
    recallMaj,  precisionMaj, fMaj, supportMaj = report.split()[5:9]
    recallMin,  precisionMin, fMin, supportMin = report.split()[10:14]
    recallMacro,  precisionMacro, fMacro, supportMacro = report.split()[19:23]
    accuracy = report.split()[15]
    
    # Save to CSV file
    myCsvRow = [seed, sp, str(len(bandselection)), clf.best_params_['C'], recallMaj,  precisionMaj, fMaj, supportMaj, recallMin,  precisionMin, fMin, supportMin, recallMacro,  precisionMacro, fMacro, supportMacro, accuracy]
    myCsvRow = ';'.join(map(str, myCsvRow))
    
    with open(outCsv,'a') as fd:
        fd.write(myCsvRow)
        fd.write("\n")

# %%
# Set the parameters by cross-validation

tuned_parameters = [
    {"kernel": ["linear"], "C": [1, 10, 100, 1000]}]

#scores = ["precision_macro", "recall_macro", metrics.make_scorer(metrics.f1_score, labels=[1], average='macro')]
#scores = (metrics.make_scorer(metrics.f1_score, labels=[1], average='macro'))
scores = "f1_weighted"

# ---------------------------------------------------------------------------------------------------------------------

# Run all models, for all sample datasets (no. = 10), all band combinations (no. = 3), and species (no.= 2)

for i in range(len(pathsMaj)): # Loop (and read) through sample datasets using 10 different random seeds
   
    # derive seed number from filepath
    seed = re.findall(r'\d+', pathsMaj[i])
    
    # preprare training and test datasets
    minority = Dbf5(pathsMin[i]).to_dataframe()
    minority.rename(columns={'Class':'class'}, inplace=True)
    
    majority = Dbf5(pathsMaj[i]).to_dataframe()
    majority.rename(columns={'band1':'1_red', 'band2':'1_green', 'band3':'1_blue', 'band4':'2_blue', 'band5':'2_green', 'band6':'3_red', 'band7':'4_re', 'band8':'2_nir'}, inplace=True)
    
    df = pd.concat([minority, majority], axis=0).drop(columns=['class_1', 'x', 'y', 'ID', 'index_righ'])

    print(df.head())

    
    trainDf = df.loc[df['split']=='train'] 
    testDf = df.loc[df['split']=='test']
    
    
    # Derive species from filepath
    if 'spH' in pathsMaj[i]:
        sp = 'H'
    else:
        sp = 'T'
        
    
    for b in [_3bands, _5bands, _8bands]:
        kdf = peform_k_clustering(trainDf, b, sp)
            
        print(f'Grid search is performed for species {sp} using {str(len(b))} bands and seed{str(seed)}')
        out = grid_search(trainDf, testDf, "E:\\Sync\\_Documents\\_Letter_invasives\\_Data\_models\\_bestmodel_seed{}_sp{}_b{}.sav", b, tuned_parameters, scores, sp, seed, 'E:\Sync\_Documents\_Letter_invasives\_Data\_models\_modellingOutputs.csv')
        print()
        print('_____________________________________________________')
        print()
# Out:
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.941176  0.937255  0.537255  0.013913  0.054563  0.021669
# 1     H     2_6  0.984314  0.972549  0.466667  0.028552  0.064575  0.045270
# 2     H     2_6  0.960784  0.972549  0.478431  0.049925  0.084581  0.075656
# 3     H     2_6  0.925490  0.909804  0.490196  0.028602  0.068072  0.052862
# 4     H     2_6  0.972549  0.956863  0.549020  0.028602  0.068072  0.052862
#
#        4_re     2_nir  split
# 0  0.152925  0.304192  train
# 1  0.158581  0.257337  train
# 2  0.180739  0.270967  train
# 3  0.158105  0.264038  train
# 4  0.158105  0.264038  train
# Grid search is performed for species H using 3 bands and seed['101']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.963 (+/-0.032) for {'C': 1, 'kernel': 'linear'}
# 0.973 (+/-0.010) for {'C': 10, 'kernel': 'linear'}
# 0.975 (+/-0.016) for {'C': 100, 'kernel': 'linear'}
# 0.973 (+/-0.010) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    179237
#            1       0.03      1.00      0.05        75
#
#     accuracy                           0.98    179312
#    macro avg       0.51      0.99      0.52    179312
# weighted avg       1.00      0.98      0.99    179312
#
#
# Classification matrix:
#
# [[176349   2888]
#  [     0     75]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['101']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.545 (+/-0.187) for {'C': 100, 'kernel': 'linear'}
# 0.519 (+/-0.221) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89    179237
#            1       0.00      0.41      0.00        75
#
#     accuracy                           0.80    179312
#    macro avg       0.50      0.61      0.45    179312
# weighted avg       1.00      0.80      0.89    179312
#
#
# Classification matrix:
#
# [[144289  34948]
#  [    44     31]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['101']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.969 (+/-0.028) for {'C': 1, 'kernel': 'linear'}
# 0.989 (+/-0.014) for {'C': 10, 'kernel': 'linear'}
# 0.991 (+/-0.017) for {'C': 100, 'kernel': 'linear'}
# 0.991 (+/-0.027) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    179237
#            1       0.07      0.99      0.13        75
#
#     accuracy                           0.99    179312
#    macro avg       0.53      0.99      0.56    179312
# weighted avg       1.00      0.99      1.00    179312
#
#
# Classification matrix:
#
# [[178250    987]
#  [     1     74]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.988235  0.976471  0.603922  0.013913  0.054563  0.021669
# 1     H     2_6  0.898039  0.890196  0.415686  0.028111  0.066361  0.049507
# 2     H     2_6  0.807843  0.819608  0.317647  0.022362  0.051873  0.043798
# 3     H     2_6  0.913725  0.870588  0.462745  0.028552  0.064575  0.045270
# 4     H     2_6  0.886275  0.952941  0.505882  0.015492  0.048033  0.019557
#
#        4_re     2_nir  split
# 0  0.152925  0.304192  train
# 1  0.149970  0.255501  train
# 2  0.139888  0.231354  train
# 3  0.158581  0.257337  train
# 4  0.146560  0.301455  train
# Grid search is performed for species H using 3 bands and seed['103']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.961 (+/-0.016) for {'C': 1, 'kernel': 'linear'}
# 0.971 (+/-0.022) for {'C': 10, 'kernel': 'linear'}
# 0.973 (+/-0.022) for {'C': 100, 'kernel': 'linear'}
# 0.969 (+/-0.026) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    179237
#            1       0.03      1.00      0.05        75
#
#     accuracy                           0.98    179312
#    macro avg       0.51      0.99      0.52    179312
# weighted avg       1.00      0.98      0.99    179312
#
#
# Classification matrix:
#
# [[176481   2756]
#  [     0     75]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['103']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.475 (+/-0.252) for {'C': 100, 'kernel': 'linear'}
# 0.483 (+/-0.274) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92    179237
#            1       0.00      0.41      0.00        75
#
#     accuracy                           0.84    179312
#    macro avg       0.50      0.63      0.46    179312
# weighted avg       1.00      0.84      0.91    179312
#
#
# Classification matrix:
#
# [[151242  27995]
#  [    44     31]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['103']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.976 (+/-0.032) for {'C': 1, 'kernel': 'linear'}
# 0.989 (+/-0.014) for {'C': 10, 'kernel': 'linear'}
# 0.989 (+/-0.014) for {'C': 100, 'kernel': 'linear'}
# 0.995 (+/-0.011) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    179237
#            1       0.08      1.00      0.15        75
#
#     accuracy                           1.00    179312
#    macro avg       0.54      1.00      0.57    179312
# weighted avg       1.00      1.00      1.00    179312
#
#
# Classification matrix:
#
# [[178373    864]
#  [     0     75]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.996078  0.988235  0.474510  0.028552  0.064575  0.045270
# 1     H     2_6  0.862745  0.890196  0.490196  0.014618  0.056150  0.023363
# 2     H     2_6  0.972549  0.945098  0.443137  0.049925  0.084581  0.075656
# 3     H     2_6  0.941176  0.925490  0.533333  0.049925  0.084581  0.075656
# 4     H     2_6  0.984314  0.976471  0.521569  0.028111  0.066361  0.049507
#
#        4_re     2_nir  split
# 0  0.158581  0.257337  train
# 1  0.145921  0.289632  train
# 2  0.180739  0.270967  train
# 3  0.180739  0.270967  train
# 4  0.149970  0.255501  train
# Grid search is performed for species H using 3 bands and seed['115']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.959 (+/-0.027) for {'C': 1, 'kernel': 'linear'}
# 0.971 (+/-0.040) for {'C': 10, 'kernel': 'linear'}
# 0.973 (+/-0.036) for {'C': 100, 'kernel': 'linear'}
# 0.969 (+/-0.043) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    179237
#            1       0.03      0.97      0.05        75
#
#     accuracy                           0.99    179312
#    macro avg       0.51      0.98      0.52    179312
# weighted avg       1.00      0.99      0.99    179312
#
#
# Classification matrix:
#
# [[176711   2526]
#  [     2     73]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['115']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.443 (+/-0.415) for {'C': 100, 'kernel': 'linear'}
# 0.516 (+/-0.206) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91    179237
#            1       0.00      0.31      0.00        75
#
#     accuracy                           0.84    179312
#    macro avg       0.50      0.57      0.46    179312
# weighted avg       1.00      0.84      0.91    179312
#
#
# Classification matrix:
#
# [[150933  28304]
#  [    52     23]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['115']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.969 (+/-0.033) for {'C': 1, 'kernel': 'linear'}
# 0.991 (+/-0.026) for {'C': 10, 'kernel': 'linear'}
# 0.991 (+/-0.026) for {'C': 100, 'kernel': 'linear'}
# 0.991 (+/-0.026) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    179237
#            1       0.05      1.00      0.09        75
#
#     accuracy                           0.99    179312
#    macro avg       0.52      1.00      0.54    179312
# weighted avg       1.00      0.99      1.00    179312
#
#
# Classification matrix:
#
# [[177734   1503]
#  [     0     75]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.850980  0.839216  0.474510  0.017326  0.040127  0.037932
# 1     H     2_6  0.972549  0.964706  0.545098  0.039466  0.076216  0.060218
# 2     H     2_6  0.996078  0.988235  0.560784  0.028111  0.066361  0.049507
# 3     H     2_6  0.886275  0.952941  0.505882  0.015492  0.048033  0.019557
# 4     H     2_6  0.792157  0.823529  0.454902  0.015492  0.048033  0.019557
#
#        4_re     2_nir  split
# 0  0.106297  0.184050  train
# 1  0.174205  0.277692  train
# 2  0.149970  0.255501  train
# 3  0.146560  0.301455  train
# 4  0.146560  0.301455  train
# Grid search is performed for species H using 3 bands and seed['120']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.963 (+/-0.021) for {'C': 1, 'kernel': 'linear'}
# 0.967 (+/-0.019) for {'C': 10, 'kernel': 'linear'}
# 0.964 (+/-0.016) for {'C': 100, 'kernel': 'linear'}
# 0.967 (+/-0.013) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    179237
#            1       0.02      1.00      0.05        75
#
#     accuracy                           0.98    179312
#    macro avg       0.51      0.99      0.52    179312
# weighted avg       1.00      0.98      0.99    179312
#
#
# Classification matrix:
#
# [[176112   3125]
#  [     0     75]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['120']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.400 (+/-0.356) for {'C': 100, 'kernel': 'linear'}
# 0.464 (+/-0.222) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92    179237
#            1       0.00      0.37      0.00        75
#
#     accuracy                           0.85    179312
#    macro avg       0.50      0.61      0.46    179312
# weighted avg       1.00      0.85      0.92    179312
#
#
# Classification matrix:
#
# [[152938  26299]
#  [    47     28]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['120']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.970 (+/-0.041) for {'C': 1, 'kernel': 'linear'}
# 0.989 (+/-0.024) for {'C': 10, 'kernel': 'linear'}
# 0.991 (+/-0.017) for {'C': 100, 'kernel': 'linear'}
# 0.991 (+/-0.017) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    179237
#            1       0.06      1.00      0.11        75
#
#     accuracy                           0.99    179312
#    macro avg       0.53      1.00      0.56    179312
# weighted avg       1.00      0.99      1.00    179312
#
#
# Classification matrix:
#
# [[178070   1167]
#  [     0     75]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.929412  0.901961  0.415686  0.028552  0.064575  0.045270
# 1     H     2_6  0.945098  0.913725  0.494118  0.028552  0.064575  0.045270
# 2     H     2_6  0.972549  0.956863  0.549020  0.028602  0.068072  0.052862
# 3     H     2_6  0.862745  0.890196  0.490196  0.014618  0.056150  0.023363
# 4     H     2_6  0.835294  0.831373  0.415686  0.029232  0.067623  0.046863
#
#        4_re     2_nir  split
# 0  0.158581  0.257337  train
# 1  0.158581  0.257337  train
# 2  0.158105  0.264038  train
# 3  0.145921  0.289632  train
# 4  0.166766  0.277317  train
# Grid search is performed for species H using 3 bands and seed['19']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.959 (+/-0.051) for {'C': 1, 'kernel': 'linear'}
# 0.971 (+/-0.040) for {'C': 10, 'kernel': 'linear'}
# 0.973 (+/-0.045) for {'C': 100, 'kernel': 'linear'}
# 0.973 (+/-0.045) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    179237
#            1       0.03      0.99      0.05        75
#
#     accuracy                           0.99    179312
#    macro avg       0.51      0.99      0.52    179312
# weighted avg       1.00      0.99      0.99    179312
#
#
# Classification matrix:
#
# [[176648   2589]
#  [     1     74]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['19']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.369 (+/-0.428) for {'C': 100, 'kernel': 'linear'}
# 0.479 (+/-0.185) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91    179237
#            1       0.00      0.41      0.00        75
#
#     accuracy                           0.84    179312
#    macro avg       0.50      0.63      0.46    179312
# weighted avg       1.00      0.84      0.91    179312
#
#
# Classification matrix:
#
# [[150869  28368]
#  [    44     31]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['19']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.969 (+/-0.025) for {'C': 1, 'kernel': 'linear'}
# 0.980 (+/-0.009) for {'C': 10, 'kernel': 'linear'}
# 0.987 (+/-0.017) for {'C': 100, 'kernel': 'linear'}
# 0.989 (+/-0.020) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    179237
#            1       0.08      1.00      0.15        75
#
#     accuracy                           1.00    179312
#    macro avg       0.54      1.00      0.58    179312
# weighted avg       1.00      1.00      1.00    179312
#
#
# Classification matrix:
#
# [[178411    826]
#  [     0     75]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.862745  0.890196  0.490196  0.014618  0.056150  0.023363
# 1     H     2_6  0.913725  0.870588  0.462745  0.028552  0.064575  0.045270
# 2     H     2_6  0.905882  0.874510  0.509804  0.030825  0.069795  0.054258
# 3     H     2_6  0.843137  0.819608  0.415686  0.028602  0.068072  0.052862
# 4     H     2_6  0.807843  0.819608  0.317647  0.022362  0.051873  0.043798
#
#        4_re     2_nir  split
# 0  0.145921  0.289632  train
# 1  0.158581  0.257337  train
# 2  0.162296  0.263685  train
# 3  0.158105  0.264038  train
# 4  0.139888  0.231354  train
# Grid search is performed for species H using 3 bands and seed['4']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.961 (+/-0.026) for {'C': 1, 'kernel': 'linear'}
# 0.978 (+/-0.024) for {'C': 10, 'kernel': 'linear'}
# 0.978 (+/-0.028) for {'C': 100, 'kernel': 'linear'}
# 0.975 (+/-0.022) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    179237
#            1       0.02      0.99      0.05        75
#
#     accuracy                           0.98    179312
#    macro avg       0.51      0.98      0.52    179312
# weighted avg       1.00      0.98      0.99    179312
#
#
# Classification matrix:
#
# [[176126   3111]
#  [     1     74]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['4']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.250 (+/-0.374) for {'C': 100, 'kernel': 'linear'}
# 0.348 (+/-0.258) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93    179237
#            1       0.00      0.40      0.00        75
#
#     accuracy                           0.87    179312
#    macro avg       0.50      0.63      0.47    179312
# weighted avg       1.00      0.87      0.93    179312
#
#
# Classification matrix:
#
# [[155473  23764]
#  [    45     30]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['4']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.969 (+/-0.039) for {'C': 1, 'kernel': 'linear'}
# 0.987 (+/-0.026) for {'C': 10, 'kernel': 'linear'}
# 0.987 (+/-0.033) for {'C': 100, 'kernel': 'linear'}
# 0.993 (+/-0.027) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    179237
#            1       0.08      1.00      0.15        75
#
#     accuracy                           1.00    179312
#    macro avg       0.54      1.00      0.57    179312
# weighted avg       1.00      1.00      1.00    179312
#
#
# Classification matrix:
#
# [[178381    856]
#  [     0     75]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.945098  0.913725  0.494118  0.028552  0.064575  0.045270
# 1     H     2_6  0.905882  0.898039  0.454902  0.026279  0.065374  0.048153
# 2     H     2_6  0.850980  0.839216  0.474510  0.017326  0.040127  0.037932
# 3     H     2_6  0.898039  0.913725  0.541176  0.014857  0.059494  0.021818
# 4     H     2_6  0.807843  0.819608  0.317647  0.022362  0.051873  0.043798
#
#        4_re     2_nir  split
# 0  0.158581  0.257337  train
# 1  0.159414  0.261526  train
# 2  0.106297  0.184050  train
# 3  0.167025  0.317565  train
# 4  0.139888  0.231354  train
# Grid search is performed for species H using 3 bands and seed['54']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.963 (+/-0.028) for {'C': 1, 'kernel': 'linear'}
# 0.978 (+/-0.027) for {'C': 10, 'kernel': 'linear'}
# 0.980 (+/-0.016) for {'C': 100, 'kernel': 'linear'}
# 0.980 (+/-0.016) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    179237
#            1       0.03      1.00      0.05        75
#
#     accuracy                           0.98    179312
#    macro avg       0.51      0.99      0.52    179312
# weighted avg       1.00      0.98      0.99    179312
#
#
# Classification matrix:
#
# [[176461   2776]
#  [     0     75]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['54']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.394 (+/-0.187) for {'C': 100, 'kernel': 'linear'}
# 0.508 (+/-0.255) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90    179237
#            1       0.00      0.41      0.00        75
#
#     accuracy                           0.82    179312
#    macro avg       0.50      0.62      0.45    179312
# weighted avg       1.00      0.82      0.90    179312
#
#
# Classification matrix:
#
# [[146941  32296]
#  [    44     31]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['54']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.971 (+/-0.033) for {'C': 1, 'kernel': 'linear'}
# 0.991 (+/-0.022) for {'C': 10, 'kernel': 'linear'}
# 0.993 (+/-0.018) for {'C': 100, 'kernel': 'linear'}
# 0.996 (+/-0.018) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    179237
#            1       0.06      0.99      0.12        75
#
#     accuracy                           0.99    179312
#    macro avg       0.53      0.99      0.56    179312
# weighted avg       1.00      0.99      1.00    179312
#
#
# Classification matrix:
#
# [[178135   1102]
#  [     1     74]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.956863  0.988235  0.537255  0.014857  0.059494  0.021818
# 1     H     2_6  0.945098  0.913725  0.494118  0.028552  0.064575  0.045270
# 2     H     2_6  0.878431  0.835294  0.478431  0.032502  0.072555  0.051897
# 3     H     2_6  0.843137  0.819608  0.415686  0.028602  0.068072  0.052862
# 4     H     2_6  0.886275  0.952941  0.505882  0.015492  0.048033  0.019557
#
#        4_re     2_nir  split
# 0  0.167025  0.317565  train
# 1  0.158581  0.257337  train
# 2  0.178779  0.287114  train
# 3  0.158105  0.264038  train
# 4  0.146560  0.301455  train
# Grid search is performed for species H using 3 bands and seed['7']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.956 (+/-0.031) for {'C': 1, 'kernel': 'linear'}
# 0.973 (+/-0.011) for {'C': 10, 'kernel': 'linear'}
# 0.977 (+/-0.000) for {'C': 100, 'kernel': 'linear'}
# 0.975 (+/-0.010) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    179237
#            1       0.03      0.99      0.06        75
#
#     accuracy                           0.99    179312
#    macro avg       0.51      0.99      0.53    179312
# weighted avg       1.00      0.99      0.99    179312
#
#
# Classification matrix:
#
# [[176798   2439]
#  [     1     74]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['7']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.333 (+/-0.250) for {'C': 100, 'kernel': 'linear'}
# 0.446 (+/-0.154) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92    179237
#            1       0.00      0.40      0.00        75
#
#     accuracy                           0.85    179312
#    macro avg       0.50      0.62      0.46    179312
# weighted avg       1.00      0.85      0.92    179312
#
#
# Classification matrix:
#
# [[152048  27189]
#  [    45     30]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['7']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.974 (+/-0.029) for {'C': 1, 'kernel': 'linear'}
# 0.986 (+/-0.009) for {'C': 10, 'kernel': 'linear'}
# 0.989 (+/-0.014) for {'C': 100, 'kernel': 'linear'}
# 0.993 (+/-0.011) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    179237
#            1       0.08      1.00      0.15        75
#
#     accuracy                           1.00    179312
#    macro avg       0.54      1.00      0.57    179312
# weighted avg       1.00      1.00      1.00    179312
#
#
# Classification matrix:
#
# [[178364    873]
#  [     0     75]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.901961  0.843137  0.443137  0.030825  0.069795  0.054258
# 1     H     2_6  0.792157  0.788235  0.368627  0.014857  0.059494  0.021818
# 2     H     2_6  0.905882  0.874510  0.509804  0.030825  0.069795  0.054258
# 3     H     2_6  0.964706  0.996078  0.537255  0.014857  0.059494  0.021818
# 4     H     2_6  0.894118  0.933333  0.588235  0.012600  0.032076  0.019625
#
#        4_re     2_nir  split
# 0  0.162296  0.263685  train
# 1  0.167025  0.317565  train
# 2  0.162296  0.263685  train
# 3  0.167025  0.317565  train
# 4  0.102736  0.194294  train
# Grid search is performed for species H using 3 bands and seed['83']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 10, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.956 (+/-0.013) for {'C': 1, 'kernel': 'linear'}
# 0.975 (+/-0.022) for {'C': 10, 'kernel': 'linear'}
# 0.973 (+/-0.018) for {'C': 100, 'kernel': 'linear'}
# 0.975 (+/-0.022) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    179237
#            1       0.02      1.00      0.05        75
#
#     accuracy                           0.98    179312
#    macro avg       0.51      0.99      0.52    179312
# weighted avg       1.00      0.98      0.99    179312
#
#
# Classification matrix:
#
# [[176252   2985]
#  [     0     75]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['83']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.446 (+/-0.215) for {'C': 100, 'kernel': 'linear'}
# 0.487 (+/-0.204) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91    179237
#            1       0.00      0.47      0.00        75
#
#     accuracy                           0.84    179312
#    macro avg       0.50      0.65      0.46    179312
# weighted avg       1.00      0.84      0.91    179312
#
#
# Classification matrix:
#
# [[150788  28449]
#  [    40     35]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['83']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.974 (+/-0.036) for {'C': 1, 'kernel': 'linear'}
# 0.987 (+/-0.026) for {'C': 10, 'kernel': 'linear'}
# 0.991 (+/-0.017) for {'C': 100, 'kernel': 'linear'}
# 0.993 (+/-0.011) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    179237
#            1       0.09      1.00      0.16        75
#
#     accuracy                           1.00    179312
#    macro avg       0.54      1.00      0.58    179312
# weighted avg       1.00      1.00      1.00    179312
#
#
# Classification matrix:
#
# [[178442    795]
#  [     0     75]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     H     2_6  0.878431  0.835294  0.478431  0.032502  0.072555  0.051897
# 1     H     2_6  0.933333  0.996078  0.572549  0.015492  0.048033  0.019557
# 2     H     2_6  0.960784  0.980392  0.603922  0.014857  0.059494  0.021818
# 3     H     2_6  0.960784  0.960784  0.607843  0.013913  0.054563  0.021669
# 4     H     2_6  0.858824  0.921569  0.490196  0.015492  0.048033  0.019557
#
#        4_re     2_nir  split
# 0  0.178779  0.287114  train
# 1  0.146560  0.301455  train
# 2  0.167025  0.317565  train
# 3  0.152925  0.304192  train
# 4  0.146560  0.301455  train
# Grid search is performed for species H using 3 bands and seed['9']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.950 (+/-0.022) for {'C': 1, 'kernel': 'linear'}
# 0.964 (+/-0.017) for {'C': 10, 'kernel': 'linear'}
# 0.969 (+/-0.026) for {'C': 100, 'kernel': 'linear'}
# 0.973 (+/-0.028) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    179237
#            1       0.03      1.00      0.05        75
#
#     accuracy                           0.98    179312
#    macro avg       0.51      0.99      0.52    179312
# weighted avg       1.00      0.98      0.99    179312
#
#
# Classification matrix:
#
# [[176527   2710]
#  [     0     75]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 5 bands and seed['9']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.000 (+/-0.000) for {'C': 1, 'kernel': 'linear'}
# 0.000 (+/-0.000) for {'C': 10, 'kernel': 'linear'}
# 0.357 (+/-0.275) for {'C': 100, 'kernel': 'linear'}
# 0.490 (+/-0.247) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92    179237
#            1       0.00      0.35      0.00        75
#
#     accuracy                           0.85    179312
#    macro avg       0.50      0.60      0.46    179312
# weighted avg       1.00      0.85      0.92    179312
#
#
# Classification matrix:
#
# [[152491  26746]
#  [    49     26]]
#
#
# _____________________________________________________
#
# Grid search is performed for species H using 8 bands and seed['9']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.972 (+/-0.040) for {'C': 1, 'kernel': 'linear'}
# 0.984 (+/-0.022) for {'C': 10, 'kernel': 'linear'}
# 0.989 (+/-0.020) for {'C': 100, 'kernel': 'linear'}
# 0.993 (+/-0.011) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    179237
#            1       0.09      1.00      0.17        75
#
#     accuracy                           1.00    179312
#    macro avg       0.55      1.00      0.58    179312
# weighted avg       1.00      1.00      1.00    179312
#
#
# Classification matrix:
#
# [[178504    733]
#  [     0     75]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     T     2_5  0.862745  0.874510  0.807843  0.050296  0.066287  0.081393
# 1     T     2_5  0.905882  0.847059  0.803922  0.043334  0.065562  0.078456
# 2     T     2_5  0.831373  0.878431  0.764706  0.044948  0.064098  0.076814
# 3     T     2_5  0.729412  0.729412  0.729412  0.060179  0.067507  0.102144
# 4     T     2_5  0.764706  0.776471  0.658824  0.042582  0.063089  0.072590
#
#        4_re     2_nir  split
# 0  0.190787  0.299465  train
# 1  0.191140  0.290811  train
# 2  0.176724  0.271577  train
# 3  0.235152  0.345466  train
# 4  0.179737  0.287559  train
# Grid search is performed for species T using 3 bands and seed['101']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.959 (+/-0.016) for {'C': 1, 'kernel': 'linear'}
# 0.981 (+/-0.013) for {'C': 10, 'kernel': 'linear'}
# 0.981 (+/-0.020) for {'C': 100, 'kernel': 'linear'}
# 0.983 (+/-0.011) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.03      0.99      0.07        98
#
#     accuracy                           0.98    176240
#    macro avg       0.52      0.99      0.53    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[173379   2763]
#  [     1     97]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 5 bands and seed['101']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.870 (+/-0.072) for {'C': 1, 'kernel': 'linear'}
# 0.969 (+/-0.040) for {'C': 10, 'kernel': 'linear'}
# 0.986 (+/-0.023) for {'C': 100, 'kernel': 'linear'}
# 0.995 (+/-0.009) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    176142
#            1       0.07      1.00      0.13        98
#
#     accuracy                           0.99    176240
#    macro avg       0.53      1.00      0.56    176240
# weighted avg       1.00      0.99      1.00    176240
#
#
# Classification matrix:
#
# [[174837   1305]
#  [     0     98]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 8 bands and seed['101']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.972 (+/-0.030) for {'C': 1, 'kernel': 'linear'}
# 0.983 (+/-0.024) for {'C': 10, 'kernel': 'linear'}
# 0.993 (+/-0.013) for {'C': 100, 'kernel': 'linear'}
# 0.997 (+/-0.008) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.02      1.00      0.04        98
#
#     accuracy                           0.98    176240
#    macro avg       0.51      0.99      0.52    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[171753   4389]
#  [     0     98]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     T     2_5  0.729412  0.764706  0.721569  0.055740  0.072167  0.095289
# 1     T     2_5  0.843137  0.819608  0.803922  0.060179  0.067507  0.102144
# 2     T     2_5  0.701961  0.654902  0.611765  0.035266  0.045313  0.056093
# 3     T     2_5  0.905882  0.847059  0.803922  0.043334  0.065562  0.078456
# 4     T     2_5  0.976471  0.894118  0.784314  0.044446  0.067656  0.094004
#
#        4_re     2_nir  split
# 0  0.206737  0.306584  train
# 1  0.235152  0.345466  train
# 2  0.120536  0.205970  train
# 3  0.191140  0.290811  train
# 4  0.251651  0.345704  train
# Grid search is performed for species T using 3 bands and seed['103']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.956 (+/-0.028) for {'C': 1, 'kernel': 'linear'}
# 0.979 (+/-0.018) for {'C': 10, 'kernel': 'linear'}
# 0.983 (+/-0.011) for {'C': 100, 'kernel': 'linear'}
# 0.983 (+/-0.011) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.03      1.00      0.06        98
#
#     accuracy                           0.98    176240
#    macro avg       0.51      0.99      0.52    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[172898   3244]
#  [     0     98]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 5 bands and seed['103']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.872 (+/-0.040) for {'C': 1, 'kernel': 'linear'}
# 0.966 (+/-0.029) for {'C': 10, 'kernel': 'linear'}
# 0.990 (+/-0.013) for {'C': 100, 'kernel': 'linear'}
# 0.995 (+/-0.009) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    176142
#            1       0.07      1.00      0.13        98
#
#     accuracy                           0.99    176240
#    macro avg       0.53      1.00      0.56    176240
# weighted avg       1.00      0.99      1.00    176240
#
#
# Classification matrix:
#
# [[174839   1303]
#  [     0     98]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 8 bands and seed['103']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.971 (+/-0.030) for {'C': 1, 'kernel': 'linear'}
# 0.983 (+/-0.019) for {'C': 10, 'kernel': 'linear'}
# 0.993 (+/-0.020) for {'C': 100, 'kernel': 'linear'}
# 0.997 (+/-0.008) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.03      1.00      0.06        98
#
#     accuracy                           0.98    176240
#    macro avg       0.51      0.99      0.52    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[172970   3172]
#  [     0     98]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     T     2_5  0.513726  0.490196  0.494118  0.047782  0.062327  0.078561
# ...
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     T     2_5  0.800000  0.792157  0.682353  0.051564  0.070792  0.085943
# 1     T     2_5  0.764706  0.776471  0.658824  0.042582  0.063089  0.072590
# 2     T     2_5  0.882353  0.870588  0.827451  0.059621  0.089784  0.094853
# 3     T     2_5  0.698039  0.670588  0.627451  0.032536  0.044868  0.055575
# 4     T     2_5  0.901961  0.882353  0.823529  0.059621  0.089784  0.094853
#
#        4_re     2_nir  split
# 0  0.204714  0.314177  train
# 1  0.179737  0.287559  train
# 2  0.242939  0.367460  train
# 3  0.133864  0.221446  train
# 4  0.242939  0.367460  train
# Grid search is performed for species T using 3 bands and seed['54']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.958 (+/-0.044) for {'C': 1, 'kernel': 'linear'}
# 0.976 (+/-0.016) for {'C': 10, 'kernel': 'linear'}
# 0.983 (+/-0.021) for {'C': 100, 'kernel': 'linear'}
# 0.988 (+/-0.014) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.03      0.99      0.05        98
#
#     accuracy                           0.98    176240
#    macro avg       0.51      0.98      0.52    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[172636   3506]
#  [     1     97]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 5 bands and seed['54']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.862 (+/-0.073) for {'C': 1, 'kernel': 'linear'}
# 0.969 (+/-0.032) for {'C': 10, 'kernel': 'linear'}
# 0.990 (+/-0.020) for {'C': 100, 'kernel': 'linear'}
# 0.995 (+/-0.009) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    176142
#            1       0.07      1.00      0.13        98
#
#     accuracy                           0.99    176240
#    macro avg       0.53      1.00      0.56    176240
# weighted avg       1.00      0.99      1.00    176240
#
#
# Classification matrix:
#
# [[174806   1336]
#  [     0     98]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 8 bands and seed['54']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.971 (+/-0.017) for {'C': 1, 'kernel': 'linear'}
# 0.985 (+/-0.013) for {'C': 10, 'kernel': 'linear'}
# 0.993 (+/-0.013) for {'C': 100, 'kernel': 'linear'}
# 0.998 (+/-0.007) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.03      1.00      0.06        98
#
#     accuracy                           0.98    176240
#    macro avg       0.52      0.99      0.53    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[173188   2954]
#  [     0     98]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     T     2_5  0.901961  0.882353  0.823529  0.059621  0.089784  0.094853
# 1     T     2_5  0.882353  0.870588  0.827451  0.059621  0.089784  0.094853
# 2     T     2_5  0.815686  0.819608  0.756863  0.045750  0.067524  0.075535
# 3     T     2_5  0.686275  0.698039  0.568627  0.044136  0.071399  0.073731
# 4     T     2_5  0.862745  0.839216  0.843137  0.041478  0.054304  0.070834
#
#        4_re     2_nir  split
# 0  0.242939  0.367460  train
# 1  0.242939  0.367460  train
# 2  0.171372  0.269292  train
# 3  0.127182  0.209609  train
# 4  0.146633  0.238756  train
# Grid search is performed for species T using 3 bands and seed['7']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.968 (+/-0.035) for {'C': 1, 'kernel': 'linear'}
# 0.981 (+/-0.034) for {'C': 10, 'kernel': 'linear'}
# 0.985 (+/-0.022) for {'C': 100, 'kernel': 'linear'}
# 0.986 (+/-0.025) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.03      0.99      0.06        98
#
#     accuracy                           0.98    176240
#    macro avg       0.52      0.99      0.53    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[173282   2860]
#  [     1     97]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 5 bands and seed['7']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.875 (+/-0.061) for {'C': 1, 'kernel': 'linear'}
# 0.966 (+/-0.022) for {'C': 10, 'kernel': 'linear'}
# 0.984 (+/-0.026) for {'C': 100, 'kernel': 'linear'}
# 0.996 (+/-0.009) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    176142
#            1       0.08      1.00      0.14        98
#
#     accuracy                           0.99    176240
#    macro avg       0.54      1.00      0.57    176240
# weighted avg       1.00      0.99      1.00    176240
#
#
# Classification matrix:
#
# [[174982   1160]
#  [     0     98]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 8 bands and seed['7']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.976 (+/-0.013) for {'C': 1, 'kernel': 'linear'}
# 0.988 (+/-0.008) for {'C': 10, 'kernel': 'linear'}
# 0.995 (+/-0.014) for {'C': 100, 'kernel': 'linear'}
# 0.997 (+/-0.008) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    176142
#            1       0.04      1.00      0.08        98
#
#     accuracy                           0.99    176240
#    macro avg       0.52      0.99      0.54    176240
# weighted avg       1.00      0.99      0.99    176240
#
#
# Classification matrix:
#
# [[173841   2301]
#  [     0     98]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     T     2_5  0.901961  0.913725  0.772549  0.059532  0.080496  0.096656
# 1     T     2_5  0.835294  0.788235  0.800000  0.054444  0.062620  0.085473
# 2     T     2_5  0.780392  0.780392  0.694118  0.038686  0.059896  0.066159
# 3     T     2_5  0.862745  0.839216  0.843137  0.041478  0.054304  0.070834
# 4     T     2_5  0.815686  0.819608  0.756863  0.045750  0.067524  0.075535
#
#        4_re     2_nir  split
# 0  0.235069  0.354213  train
# 1  0.175158  0.268311  train
# 2  0.164551  0.276285  train
# 3  0.146633  0.238756  train
# 4  0.171372  0.269292  train
# Grid search is performed for species T using 3 bands and seed['83']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.966 (+/-0.046) for {'C': 1, 'kernel': 'linear'}
# 0.981 (+/-0.020) for {'C': 10, 'kernel': 'linear'}
# 0.983 (+/-0.019) for {'C': 100, 'kernel': 'linear'}
# 0.985 (+/-0.020) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.03      0.99      0.06        98
#
#     accuracy                           0.98    176240
#    macro avg       0.51      0.99      0.52    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[172868   3274]
#  [     1     97]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 5 bands and seed['83']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.869 (+/-0.043) for {'C': 1, 'kernel': 'linear'}
# 0.968 (+/-0.045) for {'C': 10, 'kernel': 'linear'}
# 0.988 (+/-0.014) for {'C': 100, 'kernel': 'linear'}
# 0.998 (+/-0.007) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    176142
#            1       0.07      0.99      0.13        98
#
#     accuracy                           0.99    176240
#    macro avg       0.53      0.99      0.56    176240
# weighted avg       1.00      0.99      1.00    176240
#
#
# Classification matrix:
#
# [[174822   1320]
#  [     1     97]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 8 bands and seed['83']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.971 (+/-0.022) for {'C': 1, 'kernel': 'linear'}
# 0.990 (+/-0.013) for {'C': 10, 'kernel': 'linear'}
# 0.993 (+/-0.007) for {'C': 100, 'kernel': 'linear'}
# 1.000 (+/-0.000) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    176142
#            1       0.05      0.99      0.09        98
#
#     accuracy                           0.99    176240
#    macro avg       0.52      0.99      0.54    176240
# weighted avg       1.00      0.99      0.99    176240
#
#
# Classification matrix:
#
# [[174290   1852]
#  [     1     97]]
#
#
# _____________________________________________________
#
#   class Quadrat     1_red   1_green    1_blue    2_blue   2_green     3_red  \
# 0     T     2_5  0.882353  0.870588  0.827451  0.059621  0.089784  0.094853
# 1     T     2_5  0.780392  0.780392  0.694118  0.038686  0.059896  0.066159
# 2     T     2_5  0.788235  0.819608  0.725490  0.051564  0.070792  0.085943
# 3     T     2_5  0.705882  0.745098  0.674510  0.051564  0.070792  0.085943
# 4     T     2_5  0.729412  0.729412  0.729412  0.060179  0.067507  0.102144
#
#        4_re     2_nir  split
# 0  0.242939  0.367460  train
# 1  0.164551  0.276285  train
# 2  0.204714  0.314177  train
# 3  0.204714  0.314177  train
# 4  0.235152  0.345466  train
# Grid search is performed for species T using 3 bands and seed['9']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 100, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.951 (+/-0.038) for {'C': 1, 'kernel': 'linear'}
# 0.971 (+/-0.029) for {'C': 10, 'kernel': 'linear'}
# 0.980 (+/-0.017) for {'C': 100, 'kernel': 'linear'}
# 0.980 (+/-0.023) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.03      1.00      0.06        98
#
#     accuracy                           0.98    176240
#    macro avg       0.52      0.99      0.53    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[173205   2937]
#  [     0     98]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 5 bands and seed['9']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.869 (+/-0.073) for {'C': 1, 'kernel': 'linear'}
# 0.963 (+/-0.041) for {'C': 10, 'kernel': 'linear'}
# 0.988 (+/-0.032) for {'C': 100, 'kernel': 'linear'}
# 0.995 (+/-0.009) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    176142
#            1       0.07      1.00      0.12        98
#
#     accuracy                           0.99    176240
#    macro avg       0.53      1.00      0.56    176240
# weighted avg       1.00      0.99      1.00    176240
#
#
# Classification matrix:
#
# [[174740   1402]
#  [     0     98]]
#
#
# _____________________________________________________
#
# Grid search is performed for species T using 8 bands and seed['9']
# # Tuning hyper-parameters for make_scorer(f1_score, labels=[1], average=macro)
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters set found on development set:
#
# {'C': 1000, 'kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.970 (+/-0.027) for {'C': 1, 'kernel': 'linear'}
# 0.978 (+/-0.029) for {'C': 10, 'kernel': 'linear'}
# 0.990 (+/-0.013) for {'C': 100, 'kernel': 'linear'}
# 0.998 (+/-0.007) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99    176142
#            1       0.02      1.00      0.05        98
#
#     accuracy                           0.98    176240
#    macro avg       0.51      0.99      0.52    176240
# weighted avg       1.00      0.98      0.99    176240
#
#
# Classification matrix:
#
# [[172073   4069]
#  [     0     98]]
#
#
# _____________________________________________________

# %% [markdown]
# ### Summarize output

# %%
csv = pd.read_csv("E:\\Sync\\_Documents\\_Letter_invasives\\_Data\\_models\\_modellingOutputs _edited.csv")

# %%
csv.head()
# Out:
#       Seed Species  Bands     C  Pre_maj  Rec_maj  F1_maj  Support_maj  \
# 0  ['101']       H      3   100        1     0.98    0.99       179237
# 1  ['101']       H      5   100        1     0.81    0.89       179237
# 2  ['101']       H      8   100        1     0.99    1.00       179237
# 3  ['103']       H      3   100        1     0.98    0.99       179237
# 4  ['103']       H      5  1000        1     0.84    0.92       179237
#
#    Pre_min  Rec_min  F1_min  Support_min  Pre_avg  Rec_avg  F1_avg  \
# 0     0.03     1.00    0.05           75     0.51     0.99    0.52
# 1     0.00     0.41    0.00           75     0.50     0.61    0.45
# 2     0.07     0.99    0.13           75     0.53     0.99    0.56
# 3     0.03     1.00    0.05           75     0.51     0.99    0.52
# 4     0.00     0.41    0.00           75     0.50     0.63    0.46
#
#    Support_avg  Accuracy  TP     FP  FN
# 0       179312      0.98  75   2888   0
# 1       179312      0.80  31  34948  44
# 2       179312      0.99  74    987   1
# 3       179312      0.98  75   2756   0
# 4       179312      0.84  31  27995  44

# %%
groupbyDf = csv.drop(columns=['Seed']).groupby(['Species','Bands']).agg(['max'])

# %%
groupbyDf.transpose()
# Out:
# Species                  H                                T             \
# Bands                    3          5          8          3          5
# C           min      10.00     100.00      10.00     100.00    1000.00
# Pre_maj     min       1.00       1.00       1.00       1.00       1.00
# Rec_maj     min       0.98       0.81       0.99       0.98       0.99
# F1_maj      min       0.99       0.89       1.00       0.99       1.00
# Support_maj min  179237.00  179237.00  179237.00  176142.00  176142.00
# Pre_min     min       0.02       0.00       0.05       0.03       0.06
# Rec_min     min       0.97       0.31       0.99       0.99       0.99
# F1_min      min       0.05       0.00       0.09       0.05       0.12
# Support_min min      75.00      75.00      75.00      98.00      98.00
# Pre_avg     min       0.51       0.50       0.52       0.51       0.53
# Rec_avg     min       0.98       0.57       0.99       0.98       0.99
# F1_avg      min       0.52       0.45       0.54       0.52       0.56
# Support_avg min  179312.00  179312.00  179312.00  176240.00  176240.00
# Accuracy    min       0.98       0.80       0.99       0.98       0.99
# TP          min      73.00      23.00      74.00      97.00      97.00
# FP          min    2439.00   23764.00     733.00    2763.00    1160.00
# FN          min       0.00      40.00       0.00       0.00       0.00
#
# Species
# Bands                    8
# C           min    1000.00
# Pre_maj     min       1.00
# Rec_maj     min       0.98
# F1_maj      min       0.99
# Support_maj min  176142.00
# Pre_min     min       0.02
# Rec_min     min       0.99
# F1_min      min       0.04
# Support_min min      98.00
# Pre_avg     min       0.51
# Rec_avg     min       0.99
# F1_avg      min       0.52
# Support_avg min  176240.00
# Accuracy    min       0.98
# TP          min      97.00
# FP          min    1852.00
# FN          min       0.00

# %% [markdown]
# ### Prepare and predict raster

# %%
def predict_to_csv(gdf, svm_path, out_path):
    # Setup
    svm_model = pickle.load(open(svm_path, 'rb')) # load svm model using Pickle
    
    if 'b3' in svm_path:
        bandselection = ['band1','band2','band3']

    elif 'b5' in svm_path:
        bandselection = ['band4','band5','band6','band7','band8']

    else:
        bandselection = ['band1','band2','band3','band4','band5','band6','band7','band8']

        
    arr = gdf.loc[:,bandselection].to_numpy()
    
    with sklearn.config_context(working_memory=3000, assume_finite=False):
        prediction = svm_model.predict(arr)
        
    gdf = pd.concat([gdf, pd.Series(prediction, name='detect')],axis=1)
    gdf = gdf.loc[gdf['detect']==1]

    out_path = out_path+os.path.basename(svm_path).split('.')[0]+'.shp'
    gdf.to_file(out_path, index=False)
# Out:
# Overwriting tile_predictions.py

# %%
for path in glob.glob("E:\\Sync\\_Documents\\_Letter_invasives\\_Data\\_models\\*.sav"): 
    predict_to_csv(gdf, path, 'E:\\Sync\\_Documents\\_Letter_invasives\\_Data\\_predictions\\')
# Out:
# yes
# yes

# %% [markdown]
# ### TP, FP and FN by quadrat based on test datasets

# %%
modelPredT = ["E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp"] #,"E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp", "E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp"] 
modelPredH = ["E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['103']_spH_b3.shp", "E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['103']_spH_b5.shp", "E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['103']_spH_b8.shp"]

majTestT = gpd.read_file("E:\Sync\_Documents\_Letter_invasives\_Data\_samples\_majority_spT_seed54.shp").set_crs('EPSG:26911', allow_override=True)
majTestT = majTestT.loc[majTestT['split']=='test']
majTestH = gpd.read_file("E:\Sync\_Documents\_Letter_invasives\_Data\_samples\_majority_spH_seed103.shp").set_crs('EPSG:26911', allow_override=True)
majTestH = majTestH.loc[majTestH['split']=='test']

minTestT = gpd.read_file("E:\Sync\_Documents\_Letter_invasives\_Data\_samples\_minority_spT_seed54.shp").set_crs('EPSG:26911', allow_override=True)
minTestT = minTestT.loc[minTestT['split']=='test']
minTestH = gpd.read_file("E:\Sync\_Documents\_Letter_invasives\_Data\_samples\_minority_spH_seed103.shp").set_crs('EPSG:26911', allow_override=True)
minTestH = minTestH.loc[minTestH['split']=='test']

# %%
transects = gpd.read_file('E:\\Sync\\_Documents\\_Letter_invasives\\_Data\\Transect_grids.shp').set_crs('EPSG:26911', allow_override=True)
transects = transects.loc[:,['Quadrat', 'geometry']]
transectNames = transects['Quadrat'].unique()
print(transectNames)
# Out:
# ['3_3' '2_8' '1_2' '3_2' '3_1' '1_3' '1_1' '2_2' '2_7' '2_5' '2_9' '2_4'
#  '2_10' '2_1' '2_3' '0_0' '2_6']

# %%
def classReportByQuadrat(predGdfPaths, majTestGdf, minTestGdf, transectsGdf):
    minTestGdf2 = minTestGdf.copy()
    minTestGdf2['geometry'] = minTestGdf2.buffer(distance=0.005)
    
    paths, trans, tps, fns, fps = [], [], [], [], []
    for i in range(len(predGdfPaths)):
        pred = gpd.read_file(predGdfPaths[i]).set_crs('EPSG:26911', allow_override=True)
        pred = pred.sjoin(transectsGdf)
        
        for tr in transects['Quadrat'].unique():
            pred2 = pred.loc[pred['Quadrat']==tr,:]
            
            
            minSlct = pred2.overlay(minTestGdf2, how='intersection')
            majSlct = pred2.overlay(majTestGdf, how='intersection')
            
            tp = len(minSlct)
            fp = len(majSlct)

            fn =  len(minTestGdf2.loc[minTestGdf['Quadrat']==tr]) - tp
            
            print(modelPredT[i], 'transect: '+tr, 'tp: '+str(tp), 'fn: '+str(fn), 'fp: '+str(fp))
            
            paths.append(modelPredT[i])
            trans.append(tr)
            tps.append(tp)
            fns.append(fn)
            fps.append(fp)
    
    return(paths, trans, tps, fns, fps)

# %%
modelPredT = ["E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp", "E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp", "E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp"] 
pathsT, transT, tpsT, fnsT, fpsT = classReportByQuadrat(modelPredT, majTestT, minTestT, transects)
# Out:
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 3_3 tp: 0 fn: 0 fp: 18
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_8 tp: 0 fn: 0 fp: 207
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 1_2 tp: 0 fn: 0 fp: 163
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 3_2 tp: 0 fn: 0 fp: 60
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 3_1 tp: 0 fn: 0 fp: 119
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 1_3 tp: 0 fn: 0 fp: 8
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 1_1 tp: 0 fn: 0 fp: 145
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_2 tp: 30 fn: 0 fp: 314
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_7 tp: 2 fn: 0 fp: 150
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_5 tp: 9 fn: 0 fp: 540
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_9 tp: 0 fn: 0 fp: 174
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_4 tp: 29 fn: 0 fp: 403
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_10 tp: 0 fn: 0 fp: 28
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_1 tp: 1 fn: 0 fp: 344
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_3 tp: 22 fn: 1 fp: 482
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 0_0 tp: 0 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_6 tp: 4 fn: 0 fp: 354
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 3_3 tp: 0 fn: 0 fp: 17
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_8 tp: 0 fn: 0 fp: 4
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 1_2 tp: 0 fn: 0 fp: 336
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 3_2 tp: 0 fn: 0 fp: 46
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 3_1 tp: 0 fn: 0 fp: 111
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 1_3 tp: 0 fn: 0 fp: 28
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 1_1 tp: 0 fn: 0 fp: 128
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_2 tp: 30 fn: 0 fp: 210
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_7 tp: 2 fn: 0 fp: 21
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_5 tp: 9 fn: 0 fp: 88
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_9 tp: 0 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_4 tp: 29 fn: 0 fp: 118
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_10 tp: 0 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_1 tp: 1 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_3 tp: 23 fn: 0 fp: 172
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 0_0 tp: 0 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_6 tp: 4 fn: 0 fp: 58
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 3_3 tp: 0 fn: 0 fp: 12
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_8 tp: 0 fn: 0 fp: 36
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 1_2 tp: 0 fn: 0 fp: 282
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 3_2 tp: 0 fn: 0 fp: 379
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 3_1 tp: 0 fn: 0 fp: 306
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 1_3 tp: 0 fn: 0 fp: 19
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 1_1 tp: 0 fn: 0 fp: 152
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_2 tp: 30 fn: 0 fp: 199
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_7 tp: 2 fn: 0 fp: 88
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_5 tp: 9 fn: 0 fp: 417
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_9 tp: 0 fn: 0 fp: 27
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_4 tp: 29 fn: 0 fp: 283
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_10 tp: 0 fn: 0 fp: 7
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_1 tp: 1 fn: 0 fp: 51
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_3 tp: 23 fn: 0 fp: 343
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 0_0 tp: 0 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_6 tp: 4 fn: 0 fp: 354

# %%
modelPredH = ["E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['103']_spH_b3.shp", "E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['103']_spH_b5.shp", "E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['103']_spH_b8.shp"]
pathsH, transH, tpsH, fnsH, fpsH = classReportByQuadrat(modelPredH, majTestH, minTestH, transects)
# Out:
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 3_3 tp: 0 fn: 0 fp: 179
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_8 tp: 0 fn: 0 fp: 23
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 1_2 tp: 0 fn: 0 fp: 74
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 3_2 tp: 0 fn: 0 fp: 1926
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 3_1 tp: 0 fn: 0 fp: 290
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 1_3 tp: 2 fn: 0 fp: 57
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 1_1 tp: 0 fn: 0 fp: 89
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_2 tp: 0 fn: 0 fp: 2
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_7 tp: 0 fn: 0 fp: 13
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_5 tp: 21 fn: 0 fp: 31
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_9 tp: 0 fn: 0 fp: 3
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_4 tp: 12 fn: 0 fp: 20
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_10 tp: 0 fn: 0 fp: 6
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_1 tp: 0 fn: 0 fp: 6
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_3 tp: 23 fn: 1 fp: 9
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 0_0 tp: 0 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b3.shp transect: 2_6 tp: 16 fn: 0 fp: 28
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 3_3 tp: 0 fn: 0 fp: 23
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_8 tp: 0 fn: 0 fp: 1475
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 1_2 tp: 0 fn: 0 fp: 497
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 3_2 tp: 0 fn: 0 fp: 44
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 3_1 tp: 0 fn: 0 fp: 628
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 1_3 tp: 0 fn: 2 fp: 225
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 1_1 tp: 0 fn: 0 fp: 425
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_2 tp: 0 fn: 0 fp: 3378
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_7 tp: 0 fn: 0 fp: 2072
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_5 tp: 7 fn: 14 fp: 3970
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_9 tp: 0 fn: 0 fp: 1158
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_4 tp: 4 fn: 8 fp: 3647
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_10 tp: 0 fn: 0 fp: 368
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_1 tp: 0 fn: 0 fp: 2037
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_3 tp: 11 fn: 13 fp: 5693
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 0_0 tp: 0 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b5.shp transect: 2_6 tp: 9 fn: 7 fp: 2362
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 3_3 tp: 0 fn: 0 fp: 104
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_8 tp: 0 fn: 0 fp: 25
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 1_2 tp: 0 fn: 0 fp: 45
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 3_2 tp: 0 fn: 0 fp: 288
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 3_1 tp: 0 fn: 0 fp: 40
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 1_3 tp: 2 fn: 0 fp: 13
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 1_1 tp: 0 fn: 0 fp: 51
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_2 tp: 0 fn: 0 fp: 17
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_7 tp: 0 fn: 0 fp: 11
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_5 tp: 21 fn: 0 fp: 47
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_9 tp: 0 fn: 0 fp: 57
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_4 tp: 12 fn: 0 fp: 47
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_10 tp: 0 fn: 0 fp: 17
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_1 tp: 0 fn: 0 fp: 37
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_3 tp: 23 fn: 1 fp: 28
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 0_0 tp: 0 fn: 0 fp: 0
# E:\Sync\_Documents\_Letter_invasives\_Data\_predictions\_bestmodel_seed['54']_spT_b8.shp transect: 2_6 tp: 16 fn: 0 fp: 37

# %%
dfH = pd.DataFrame({'path': pathsH, 'quadrat': transH, 'TP': tpsH, 'FN': fnsH, 'FP':fpsH})
dfH.to_csv("E:\\Sync\\_Documents\\_Letter_invasives\\_Data\\_byquadrat\\hawkweed.csv")
